# %% [markdown]
# #01. Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
#Python Data Types

# %% [markdown]
# #02. Integers

# %%
x=2

# %%
print(x)
# Out:
# 2

# %%
type(x)
# Out:
# int

# %%
x + 4
# Out:
# 6

# %%
x = x + 4

# %%
print(x)
# Out:
# 6

# %% [markdown]
# #Step 7: Code 3 different ways of reaching a result of 100 by adding or subtracting numeric variables.

# %%
#Example 1: 45+55 = 100

# %%
a = 45

# %%
b = 55

# %%
a + b
# Out:
# 100

# %%
#Example 2: 150 - 50 = 100

# %%
x = 150

# %%
y = 50

# %%
x - y
# Out:
# 100

# %%
#Example 3: (200 - 75) - 25 = 100

# %%
x = 200

# %%
y = 75

# %%
z = 25

# %%
(x - y) - z
# Out:
# 100

# %% [markdown]
# #03. Floating-point numbers

# %%
y = 5.678

# %%
type(y)
# Out:
# float

# %%
x + y
# Out:
# 7.678

# %% [markdown]
# #Step 8: Code 2 floating-point variables and divide them by each other.

# %%
a = 25.5

# %%
b = 2.5

# %%
a/b
# Out:
# 10.2

# %%
type (a), type (b), type (a/b)
# Out:
# (float, float, float)

# %%
x = 18.75

# %%
y = 3.5

# %%
x/y
# Out:
# 5.357142857142857

# %%
type (x), type (y), type (x/y)
# Out:
# (float, float, float)

# %%
#04. Strings

# %%
z = 'Brazil'

# %%
type(z)
# Out:
# str

# %%
type(Mania)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 type(Mania)
#
# NameError: name 'Mania' is not defined

# %%
type('Mania')
# Out:
# str

# %%
a = 'Hello, '

# %%
b = 'Marley'

# %%
a + b
# Out:
# 'Hello, Marley'

# %%
n = 'potato'

# %%
n * 12
# Out:
# 'potatopotatopotatopotatopotatopotatopotatopotatopotatopotatopotatopotato'

# %% [markdown]
# #Step 9: Construct a short word made of separate strings.

# %%
l1 = 'p'

# %%
l2 = 'e'

# %%
l3 = 'a'

# %%
l4 = 'c'

# %%
l5 = 'e'

# %%
l1 + l2 + l3 + l4 + l5
# Out:
# 'peace'

# %%
s1 = 's'
s2 = 'u'
s3 = 'n'
s1 + s2 + s3
# Out:
# 'sun'

# %% [markdown]
# Step 10: Construct 2 short sentences made of separate strings

# %%
l1 = 'It '
l2 = 'is '
l3 = 'so '
l4 = 'cold'
l5 = '!'
l1 + l2 + l3 + l4 + l5
# Out:
# 'It is so cold!'

# %%
w1 = 'No '
w2 = 'good '
w3 = 'deed '
w4 = 'goes '
w5 = 'unpunished'
w6 ='.'
w1 + w2 + w3 + w4 + w5 + w6
# Out:
# 'No good deed goes unpunished.'

# %% [markdown]
# #05. Boolean

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
x == y
# Out:
# False

# %%
type(x == y)
# Out:
# bool

# %% [markdown]
# #Bonus Task: Repeat a string 100 times

# %%
"Bayleaf" * 100
# Out:
# '...'
